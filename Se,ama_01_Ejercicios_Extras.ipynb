# %% [markdown]
# <a href="https://colab.research.google.com/github/baubyte/HerramientasDeSoftwareParaElAnalisisDeDatos/blob/main/Se%2Cama_01_Ejercicios_Extras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calcular la media armónica de una secuencia de n números reales (x1, x2, ..., xn). No se conoce la longitud de la secuencia. La media armónica se define como:
#
# # $H = \frac{n}{\frac{1}{x1}+\frac{1}{x4}+\frac{1}{x3}+...+\frac{1}{xn}}$

# %% [markdown]
# Un número primo es un número natural que sólo es divisible por 1 y por sí mismo. Los números que tienen más de un divisor se llaman números compuestos. Los números 0 y 1 no son ni primo ni compuesto.
# Escribir un programa que verifique si el número ingresado es primo o compuesto. Mostrar cuales son todos los divisores del número ingresado y que además muestre la cantidad de divisores.

# %% [markdown]
# Escribir un programa que adivine el número entero que estoy pensando.
# Se debe ingresar un intervalo de trabajo con un número mínimo y un máximo. No se puede preguntar por números ya verificados o preguntados con anterioridad, las preguntas que se deben realizar son si el número que se muestra por pantalla es igual, menor o mayor al que tengo que adivinar.
# Ayuda: se puede importar el módulo random y utilizar la función random.randint(0, 10) el random incluye los extremos

# %% [markdown]
# Entre todos los enteros mayores a 1 hay solamente cuatro que pueden ser representados por la suma de los cubos de sus dígitos. Desarrolle un programa para poder determinar los números.

# %% [markdown]
# Desarrolle un programa para realizar multiplicaciones. Se debe ingresar el multiplicador y el multiplicando, y entregue como resultado el producto de ambos, calculado mediante el método de multiplicación rusa y aplicando recursión. Los números que se ingresan deben ser enteros.
# El método de multiplicación rusa consiste en multiplicar sucesivamente por 2 el multiplicando y dividir por 2 el multiplicador hasta que el multiplicador tome el valor 1 (se redondea siempre hacia abajo). Luego, se suman todos los multiplicandos correspondientes a los multiplicadores impares.
# Dicha suma es el producto de los dos números. La siguiente tabla muestra el cálculo realizado para multiplicar 37 por 12, cuyo resultado final es 12 + 48 + 384 = 444.
# Una multiplicación es: multiplicador x multiplicando = resultado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Desarrollar un programa que sume 2 números en forma recursiva siguiendo las reglas de suma de la educación básica o de la escuela primaria. Se debe sumar de derecha a izquierda, dígito por dígito y llevándome un valor si es superior a 10.
# Por ejemplo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Escribe un programa que verifique si una contraseña ingresada por el usuario cumple con ciertos criterios de seguridad, como tener al menos 8 caracteres, contener letras mayúsculas y minúsculas, y al menos un número.

# %% [markdown]
# Escribe un programa que genere una contraseña aleatoria con una longitud específica ingresada por el usuario, además el usuario deberá ingresar la cantidad de letras mayúsculas, la cantidad de letras minúsculas,la cantidad de números y la cantidad de caracteres especiales que deberá contener la contraseña.

# %% [markdown]
# Escribe una función que tome una lista de caracteres y elimine los elementos duplicados, devolviendo una nueva lista sin duplicados. El ejercicio debe estar resuelto con repeticiones.

# %% [markdown]
# Escribir un programa que calcule el resto de la división sin utilizar la función módulo y sin usar el operador de división.

# %% [markdown]
# Crea un programa que tome una cadena de texto y reemplace todas las letras mayúsculas por letras minúsculas y viceversa. Por ejemplo, si el usuario ingresa "Hola Mundo", el programa debería imprimir "hOLA mUNDO".

# %% [markdown]
# Desarrolla un programa que tome una cadena de texto y convierta la primera letra de cada palabra en mayúscula, dejando las demás letras en minúscula. Por ejemplo, si el usuario ingresa "hola mundo", el programa debería imprimir "Hola Mundo".
